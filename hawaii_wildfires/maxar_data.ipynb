# %%
import json
import dask.distributed
import folium
import folium.plugins
import rasterio
import geopandas as gpd
import shapely.geometry
from shapely.geometry import mapping
from IPython.display import HTML, display

import dask
import xarray as xr
import rioxarray as rxr
import numpy as np
import earthpy.spatial as es
import earthpy.plot as ep
import matplotlib.pyplot as plt

from odc.stac import configure_rio, load
from pystac_client import Client
import pystac

# %% [markdown]
# 1. Determine spatial extent of data we want (bounds)
# 2. Collect proper tiff files
# 3. Get imagery from before the fire
# 4. Get parcel data
# 5. Use machine vision to compare and determine if a structure is destroyed

# %% [markdown]
# ----

# %% [markdown]
# ## Reading a STAC Catalog

# %%
collection = pystac.Collection.from_file("https://maxar-opendata.s3.amazonaws.com/events/Maui-Hawaii-fires-Aug-23/collection.json")
collection
# Out:
# <Collection id=Maui-Hawaii-fires-Aug-23>
